# %%
import os
import pprint

os.environ["SERPER_API_KEY"] = "d45ec86c0e9899f654b141e78d5c74ea46247fba"
from langchain_community.utilities import GoogleSerperAPIWrapper
search = GoogleSerperAPIWrapper()
x=search.run("Obama's first name?")
print(x)
# Out:
# Barack Hussein Obama II

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.agents import AgentType, Tool, initialize_agent
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_openai import OpenAI

llm = OpenAI(temperature=0)
search = GoogleSerperAPIWrapper()
tools = [
    Tool(
        name="Intermediate Answer",
        func=search.run,
        description="useful for when you need to ask with search",
    )
]

import langchain
self_ask_with_search = langchain.agents.initialize.initialize_agent(
    tools, llm, agent=AgentType.SELF_ASK_WITH_SEARCH,verbose = True
)
self_ask_with_search.run(
    "What is the hometown of the reigning men's U.S. Open champion?"
)

# %%
search = GoogleSerperAPIWrapper()
results = search.results("Who is M.S.Dhoni?")
pprint.pp(results)
# Out:
# {'searchParameters': {'q': 'Who is M.S.Dhoni?',
#                       'gl': 'us',
#                       'hl': 'en',
#                       'type': 'search',
#                       'num': 10,
#                       'engine': 'google'},
#  'answerBox': {'snippet': 'Mahendra Singh Dhoni (/məˈheɪndrə ˈsɪŋ dhæˈnɪ/; '
#                           'born 7 July 1981) is an Indian professional '
#                           'cricketer.',
#                'snippetHighlighted': ['Indian professional cricketer'],
#                'title': 'MS Dhoni - Wikipedia',
#                'link': 'https://en.wikipedia.org/wiki/MS_Dhoni'},
#  'knowledgeGraph': {'title': 'MS Dhoni',
#                     'type': 'Indian cricketer',
#                     'description': 'Mahendra Singh Dhoni is an Indian '
#                                    'professional cricketer. He is a right '
#                                    'handed batter and a wicket-keeper.',
# ...

# %%
list=(results["relatedSearches"])
for i in range(0,len(list)):
    print(list[i]["query"])
# Out:
# Indian cricket players
# Chennai Super Kings team
# MS Dhoni wife
# MS Dhoni age
# MS Dhoni retirement age
# Who is MS Dhoni sister
# MS Dhoni dates joined
# MS Dhoni total runs
# MS Dhoni total centuries
# MS Dhoni retirement date

# %%
lst=results["peopleAlsoAsk"]
print(lst)
for i in range(0,len(lst)):
    print(lst[i]["question"])

n=int(input("Enter number:"))
print(lst[n]["snippet"])
# Out:
# [{'question': 'Why is MS Dhoni famous?', 'snippet': "Known for his calm demeanor under pressure, Dhoni is nicknamed 'Captain Cool' by his fans. He has won three ICC white ball awards: ODI World Cup, He is the only world cricket captain to win T20 World Cup and Championship Trophy. India's disastrous defeat in the T-20 World Cup in 2007 is the story of the ages.", 'title': 'Why Ms Dhoni Is Called Captain Cool - India 2023 - JUIT', 'link': 'https://www.juit.ac.in/alumni/resources/images/cricket/why-ms-dhoni-is-called-captain-cool/'}, {'question': "Who is India's No 1 captain?", 'snippet': 'Mahendra Singh Dhoni (aka Captain Cool) is arguably the most famous and successful captain of India, given his calm attitude and numerous tournament victories including; 2007 T20 World Cup, the 2011 World Cup, the 2013 Champions Trophy. Virat Kohli and Sourav Ganguly are also in the same category.', 'title': "India's Most Successful Cricket Captains: Know Who is Number 1", 'link': 'https://www.howzat
# ...

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict["brand"])
# Out:
# Ford
